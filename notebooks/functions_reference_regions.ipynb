# %%
library(rgdal)
library(sp)
library(RColorBrewer)

# %%
climate4R <- list("loadeR", "transformeR", "downscaleR", "visualizeR", "climate4R.climdex","geoprocessoR")
lapply(climate4R, require, character.only = TRUE)
# Out:
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE
#
# [[4]]
# [1] TRUE
#
# [[5]]
# [1] TRUE
#
# [[6]]
# [1] TRUE

# %%
load("./pr_JJA.rda",verbose = T)
load("./tas_JJA.rda",verbose = T)
load("./predict_pr_regression_LT1.rda",verbose=T)  
load("./predict_tas_regression_LT1.rda",verbose=T)
# Out:
# Loading objects:
#   data_JJA
# Loading objects:
#   data_JJA_temp
# Loading objects:
#   predict_pr_regression_LT1
# Loading objects:
#   predict_tas_regression_LT1

# %%
source("./functions_reference_regions.R")

# %%
reference_regions_pr(data_JJA,predict_pr_regression_LT1,"RAR")
# Out:
# Loading objects:
#   IPCC_WGI_reference_regions_v4
# Warning message in projectGrid(obs, original.CRS = proj4string(refregions)):
# “CAUTION! Grid with previusly defined projection: LatLonProjection”
# [2023-08-31 19:00:31] Arguments of the original projection defined as +proj=longlat +ellps=WGS84 +towgs84=0,0,0,0,0,0,0 +no_defs
#
# Data is already annual: 'aggr.y' option was ignored.
#
# Warning message in projectGrid(pred, original.CRS = proj4string(refregions)):
# “CAUTION! Grid with previusly defined projection: LatLonProjection”
# [2023-08-31 19:00:35] Arguments of the original projection defined as +proj=longlat +ellps=WGS84 +towgs84=0,0,0,0,0,0,0 +no_defs
#
# Data is already annual: 'aggr.y' option was ignored.
#
# pad applied on the interval: year
#
# pad applied on the interval: year
# plot without title

# %%
reference_regions_tas(data_JJA_temp, predict_tas_regression_LT1,"RAR")
# Out:
# Loading objects:
#   IPCC_WGI_reference_regions_v4
# Warning message in projectGrid(obs, original.CRS = proj4string(refregions)):
# “CAUTION! Grid with previusly defined projection: LatLonProjection”
# [2023-08-31 19:01:02] Arguments of the original projection defined as +proj=longlat +ellps=WGS84 +towgs84=0,0,0,0,0,0,0 +no_defs
#
# Data is already annual: 'aggr.y' option was ignored.
#
# Warning message in projectGrid(pred, original.CRS = proj4string(refregions)):
# “CAUTION! Grid with previusly defined projection: LatLonProjection”
# [2023-08-31 19:01:05] Arguments of the original projection defined as +proj=longlat +ellps=WGS84 +towgs84=0,0,0,0,0,0,0 +no_defs
#
# Data is already annual: 'aggr.y' option was ignored.
#
# pad applied on the interval: year
#
# pad applied on the interval: year
# plot without title
